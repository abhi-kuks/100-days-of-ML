# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#        id                              title  \
# 0     278           The Shawshank Redemption
# 1   19404        Dilwale Dulhania Le Jayenge
# 2     238                      The Godfather
# 3  545611  Everything Everywhere All at Once
# 4     424                   Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23      63.491
# 1  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      18.583
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      67.214
# 3  An aging Chinese immigrant is swept up in an i...   2022-03-24     335.704
# 4  The true story of how businessman Oskar Schind...   1993-11-30      45.345
#
#    vote_average  vote_count
# 0           8.7       21431
# 1           8.7        3649
# 2           8.7       15976
# 3           8.7         284
# 4           8.6       12765

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                              title  \
# 0        278           The Shawshank Redemption
# 1      19404        Dilwale Dulhania Le Jayenge
# 2        238                      The Godfather
# 3     545611  Everything Everywhere All at Once
# 4        424                   Schindler's List
# ...      ...                                ...
# 8555   12090                       Just Married
# 8556   11718                 Who's Harry Crumb?
# 8557    9562                           Timeline
# 8558    8836     The X Files: I Want to Believe
# 8559  714375                       Fatal Affair
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   1994-09-23
# 1     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 2     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3     An aging Chinese immigrant is swept up in an i...   2022-03-24
# 4     The true story of how businessman Oskar Schind...   1993-11-30
# ...                                                 ...          ...
# 8555  Tom Leezak and Sarah McNerney fall in love and...   2003-01-09
# 8556  Harry Crumb is a bumbling and inept private in...   1989-02-03
# 8557  A group of archaeological students become trap...   2003-11-26
# 8558  Six years after the events of The X-Files seri...   2008-07-24
# 8559  Ellie tries to mend her marriage with her husb...   2020-07-16
#
#       popularity  vote_average  vote_count
# 0         63.491           8.7       21431
# 1         18.583           8.7        3649
# 2         67.214           8.7       15976
# 3        335.704           8.7         284
# 4         45.345           8.6       12765
# ...          ...           ...         ...
# 8555      14.978           5.7        1104
# 8556       7.655           5.7         226
# 8557      11.277           5.7         858
# 8558      14.358           5.7        1204
# 8559      17.213           5.7         241
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
