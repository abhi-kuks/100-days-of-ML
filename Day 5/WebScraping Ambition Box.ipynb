# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page =1").text

# %%
soup = BeautifulSoup(webpage , 'lxml')

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# ICICI Bank
# Wipro
# HDFC Bank
# Capgemini
# HCL Technologies
# Infosys
# Tech Mahindra
# Genpact
# Axis Bank
# IBM
# Concentrix Corpo...
# Larsen & Toubro ...
# Amazon
# Reliance jio
# Vodafone Idea
# HDB Financial Se...
# Teleperformance
# Kotak Mahindra B...
# Reliance Industr...
# Bharti Airtel
# Tata Motors
# Deloitte
# Reliance Retail
# Mahindra & Mahin...
# IndusInd Bank
# WNS
# DXC Technology

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# Rate & help your company win an award!
# AmbitionBox
# Discover Best Places to Work!
# Company reviews. Salaries. Interviews. Jobs.
# About Company
# 636,990 unique
# 			companies found
# Sort By:
# Popular
# 3.9
# #6 Best Mega Company - 2021
# Public
# Mumbai,Maharashtra + 237 more
# 54 years old
# 1 Lakh+ Employees (India)
# We ensure the highest levels of certainty and satisfaction through a deep-set commitment to our clients, comprehensive industry expertise and a global network of innovation and delivery centers.
#
# We function as a full stakeholder to business, offering a consulting-led approach with an integrated portfolio of technology led solutions that encompass the entire Enterprise value chain. Our Customer-centric Engagement Model defines how we do engage with you, offering specialized services and solutions that meet the distinct needs of your business.
#
# ...

# %%
for i in soup.find_all('p' ,class_= 'rating'):
    print(i.text.strip())
# Out:
# 3.9
# 4.1
# 3.9
# 4.0
# 3.9
# 4.0
# 3.9
# 3.9
# 4.0
# 3.7
# 4.0
# 3.9
# 4.2
# 4.1
# 4.0
# 4.2
# 4.0
# 4.3
# 4.0
# 3.6
# 3.9
# 4.1
# 4.1
# 4.1
# 4.0
# 4.1
# 4.1
# 3.8
# 3.7
# 3.9

# %%
for i in soup.find_all('a' ,class_ = 'review-count'):
    print(i.text.strip())
# Out:
# (40.7k Reviews)
# (27.2k Reviews)
# (24.7k Reviews)
# (31.6k Reviews)
# (23.2k Reviews)
# (32.6k Reviews)
# (20k Reviews)
# (19.7k Reviews)
# (23.6k Reviews)
# (18.3k Reviews)
# (18.3k Reviews)
# (16.7k Reviews)
# (13.6k Reviews)
# (13.1k Reviews)
# (17.2k Reviews)
# (13k Reviews)
# (12.8k Reviews)
# (12.7k Reviews)
# (11.6k Reviews)
# (9.1k Reviews)
# (12.1k Reviews)
# (36k Reviews)
# (11.5k Reviews)
# (8.2k Reviews)
# (8k Reviews)
# (12.1k Reviews)
# (18.6k Reviews)
# (6.1k Reviews)
# (6k Reviews)
# (6k Reviews)

# %%
soup.find_all('p' , class_ ='infoEntity')
# Out:
# [<p class="infoEntity sbold-list-header"><i class="icon-domain"></i>
#  						Public
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-pin-drop"></i>
#  						Mumbai,Maharashtra + 237 more
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-access-time"></i>
#  						54 years old
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-supervisor-account"></i>
#  						1 Lakh+ Employees (India)
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-domain"></i>
#  						Public
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-pin-drop"></i>
#  						Dublin,Dublin + 132 more
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-access-time"></i>
#  						33 years old
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-supervisor-account"></i>
#  						1 Lakh+ Employees (India)
#  					</p>,
# ...

# %%
company = soup.find_all('div' , class_ ='company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name = []
rating = []
reviews =[]
ctype = []
hq =[]
old =[]
emp = []
desc= []

for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p' , class_ = 'rating').text.strip())
    reviews.append(i.find('a' ,class_ = 'review-count').text.strip())
    ctype.append(i.find_all('p' , class_='infoEntity')[0].text.strip())
    hq.append(i.find_all('p' , class_='infoEntity')[1].text.strip())
    old.append(i.find_all('p' , class_='infoEntity')[2].text.strip())
    emp.append(i.find_all('p' , class_='infoEntity')[3].text.strip())
    desc.append(i.find('p', class_ = 'description').text.strip())

# %%
d = {'name':name, 'rating': rating , 'reviews': reviews , 'type':ctype,'hq':hq , 'how_old':old ,'# of emp': emp , 'about':desc}
data = pd.DataFrame(d)

# %%
df1 = data[['name' ,'rating','reviews','type','hq','how_old','# of emp']]

# %%
df1
# Out:
#                    name rating          reviews     type  \
# 0                   TCS    3.9  (40.7k Reviews)   Public
# 1             Accenture    4.1  (27.2k Reviews)   Public
# 2             Cognizant    3.9  (24.7k Reviews)  Private
# 3            ICICI Bank    4.0  (31.6k Reviews)   Public
# 4                 Wipro    3.9  (23.2k Reviews)   Public
# 5             HDFC Bank    4.0  (32.6k Reviews)   Public
# 6             Capgemini    3.9    (20k Reviews)   Public
# 7      HCL Technologies    3.9  (19.7k Reviews)   Public
# 8               Infosys    4.0  (23.6k Reviews)   Public
# 9         Tech Mahindra    3.7  (18.3k Reviews)   Public
# 10              Genpact    4.0  (18.3k Reviews)  Private
# 11            Axis Bank    3.9  (16.7k Reviews)   Public
# 12                  IBM    4.2  (13.6k Reviews)   Public
# 13  Concentrix Corpo...    4.1  (13.1k Reviews)   Public
# 14  Larsen & Toubro ...    4.0  (17.2k Reviews)   Public
# ...

# %%
final_df = pd.DataFrame()
for j in range(1,333):
    
    url = 'https://www.ambitionbox.com/list-of-companies?page ={}'.format(j)
    webpage = requests.get(url).text
    soup = BeautifulSoup(webpage , 'lxml')
    company = soup.find_all('div' , class_ ='company-content-wrapper')
    name = []
    rating = []
    reviews =[]
    ctype = []
    hq =[]
    old =[]
    emp = []
    desc= []

    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find('p' , class_ = 'rating').text.strip())
        reviews.append(i.find('a' ,class_ = 'review-count').text.strip())
        ctype.append(i.find_all('p' , class_='infoEntity')[0].text.strip())
        hq.append(i.find_all('p' , class_='infoEntity')[1].text.strip())
        old.append(i.find_all('p' , class_='infoEntity')[2].text.strip())
        emp.append(i.find_all('p' , class_='infoEntity')[3].text.strip())
        desc.append(i.find('p', class_ = 'description').text.strip())
    d = {'name':name, 'rating': rating , 'reviews': reviews , 'type':ctype,'hq':hq , 'how_old':old ,'# of emp': emp , 'about':desc}
    df = pd.DataFrame(d)
    final_df =final_df.append(df,ignore_index=True)

# %%
final_df
# Out:
#                     name rating          reviews     type  \
# 0                    TCS    3.9  (40.7k Reviews)   Public
# 1              Accenture    4.1  (27.2k Reviews)   Public
# 2              Cognizant    3.9  (24.7k Reviews)  Private
# 3             ICICI Bank    4.0  (31.6k Reviews)   Public
# 4                  Wipro    3.9  (23.2k Reviews)   Public
# ..                   ...    ...              ...      ...
# 295      Reliance Retail    4.1  (12.1k Reviews)  Private
# 296  Mahindra & Mahin...    4.1  (18.6k Reviews)   Public
# 297        IndusInd Bank    3.8   (6.1k Reviews)   Public
# 298                  WNS    3.7     (6k Reviews)  Private
# 299       DXC Technology    3.9     (6k Reviews)   Public
#
#                                            hq       how_old  \
# 0               Mumbai,Maharashtra + 237 more  54 years old
# 1                    Dublin,Dublin + 132 more  33 years old
# 2                Teaneck,New Jersey + 88 more  28 years old
# ...

# %%
final_df
# Out:
#                      name rating          reviews     type  \
# 0                     TCS    3.9  (40.7k Reviews)   Public
# 1               Accenture    4.1  (27.2k Reviews)   Public
# 2               Cognizant    3.9  (24.7k Reviews)  Private
# 3              ICICI Bank    4.0  (31.6k Reviews)   Public
# 4                   Wipro    3.9  (23.2k Reviews)   Public
# ...                   ...    ...              ...      ...
# 9955      Reliance Retail    4.1  (12.1k Reviews)  Private
# 9956  Mahindra & Mahin...    4.1  (18.6k Reviews)   Public
# 9957        IndusInd Bank    3.8   (6.1k Reviews)   Public
# 9958                  WNS    3.7     (6k Reviews)  Private
# 9959       DXC Technology    3.9     (6k Reviews)   Public
#
#                                             hq       how_old  \
# 0                Mumbai,Maharashtra + 237 more  54 years old
# 1                     Dublin,Dublin + 132 more  33 years old
# 2                 Teaneck,New Jersey + 88 more  28 years old
# ...

# %%
final_df.to_csv('Ambition Box Top companies')

# %%
final_df.shape
# Out:
# (9960, 8)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9960 entries, 0 to 9959
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      9960 non-null   object
#  1   rating    9960 non-null   object
#  2   reviews   9960 non-null   object
#  3   type      9960 non-null   object
#  4   hq        9960 non-null   object
#  5   how_old   9960 non-null   object
#  6   # of emp  9960 non-null   object
#  7   about     9960 non-null   object
# dtypes: object(8)
# memory usage: 622.6+ KB

# %%
final_df.s
